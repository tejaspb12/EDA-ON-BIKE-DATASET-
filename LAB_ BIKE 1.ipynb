# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt1

# %% [markdown]
# TO READ THE CSV FILE

# %%
df = pd.read_csv("bike_buyers_clean.csv")
df
# Out:
#         ID Marital Status  Gender  Income  Children        Education  \
# 0    12496        Married  Female   40000         1        Bachelors
# 1    24107        Married    Male   30000         3  Partial College
# 2    14177        Married    Male   80000         5  Partial College
# 3    24381         Single    Male   70000         0        Bachelors
# 4    25597         Single    Male   30000         0        Bachelors
# ..     ...            ...     ...     ...       ...              ...
# 995  23731        Married    Male   60000         2      High School
# 996  28672         Single    Male   70000         4  Graduate Degree
# 997  11809        Married    Male   60000         2        Bachelors
# 998  19664         Single    Male  100000         3        Bachelors
# 999  12121         Single    Male   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# ...

# %% [markdown]
# CODE FOR KNOWING THE NUMBER OF FIRST ROWS

# %%
df.head()
# Out:
#       ID Marital Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %% [markdown]
# CODE FOR KNOWING THE NUMBER OF LAST ROWS

# %%
df.tail()
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 995  23731        Married   Male   60000         2      High School
# 996  28672         Single   Male   70000         4  Graduate Degree
# 997  11809        Married   Male   60000         2        Bachelors
# 998  19664         Single   Male  100000         3        Bachelors
# 999  12121         Single   Male   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 995    Professional        Yes     2        2-5 Miles  North America   54
# 996    Professional        Yes     0        2-5 Miles  North America   35
# 997  Skilled Manual        Yes     0        0-1 Miles  North America   38
# 998      Management         No     3        1-2 Miles  North America   38
# 999    Professional        Yes     2        10+ Miles  North America   53
#
#     Purchased Bike
# 995            Yes
# 996            Yes
# 997            Yes
# 998             No
# ...

# %% [markdown]
# CODE TO KNOW THE NUMBER OF ROWS AND COLUMNS OF THE DATA FRAME

# %%
df.shape
# Out:
# (1000, 13)

# %% [markdown]
# CODE TO KNOW NUMBER OF ELEMENTS IN THE DATA FRAME

# %%
df.size
# Out:
# 13000

# %% [markdown]
# TO KNOW THE SUMMARY OF THE DATASET

# %%
df.describe()
# Out:
#                  ID         Income     Children         Cars          Age
# count   1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean   19965.992000   56140.000000     1.908000     1.452000    44.190000
# std     5347.333948   31081.609779     1.626094     1.124705    11.353537
# min    11000.000000   10000.000000     0.000000     0.000000    25.000000
# 25%    15290.750000   30000.000000     0.000000     1.000000    35.000000
# 50%    19744.000000   60000.000000     2.000000     1.000000    43.000000
# 75%    24470.750000   70000.000000     3.000000     2.000000    52.000000
# max    29447.000000  170000.000000     5.000000     4.000000    89.000000

# %% [markdown]
# TO KNOW THE TYPE OF DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Income            1000 non-null   int64
#  4   Children          1000 non-null   int64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        1000 non-null   object
#  8   Cars              1000 non-null   int64
#  9   Commute Distance  1000 non-null   object
#  10  Region            1000 non-null   object
#  11  Age               1000 non-null   int64
#  12  Purchased Bike    1000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB

# %%
df.describe().T
# Out:
#            count       mean           std      min       25%      50%  \
# ID        1000.0  19965.992   5347.333948  11000.0  15290.75  19744.0
# Income    1000.0  56140.000  31081.609779  10000.0  30000.00  60000.0
# Children  1000.0      1.908      1.626094      0.0      0.00      2.0
# Cars      1000.0      1.452      1.124705      0.0      1.00      1.0
# Age       1000.0     44.190     11.353537     25.0     35.00     43.0
#
#                75%       max
# ID        24470.75   29447.0
# Income    70000.00  170000.0
# Children      3.00       5.0
# Cars          2.00       4.0
# Age          52.00      89.0

# %%
df.columns
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %% [markdown]
# TO KNOW THE UNIQUE VALUES IN THAT PARTICULAR COLUMN

# %%
df['Income'].unique()
# Out:
# array([ 40000,  30000,  80000,  70000,  10000, 160000,  20000,  90000,
#        170000,  60000, 100000, 130000, 120000, 150000,  50000, 110000],
#       dtype=int64)

# %%
np.unique(df['Commute Distance'])
# Out:
# array(['0-1 Miles', '1-2 Miles', '10+ Miles', '2-5 Miles', '5-10 Miles'],
#       dtype=object)

# %% [markdown]
# TO DROP THE COLUMNS

# %%
df.drop(columns='Purchased Bike',inplace=True)

# %% [markdown]
# TO RENAME THE COLUMN NAMES

# %%
col_names =['ID','Marital-Status','Gender','Income','Children','Education','Occupation','HomeOwner','Cars','CommuteDistance','Region','Age']
df.columns= col_names
df.columns
# Out:
# Index(['ID', 'Marital-Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'HomeOwner', 'Cars', 'CommuteDistance', 'Region', 'Age'],
#       dtype='object')

# %% [markdown]
# TO KNOW THE TOTAL OF NULL VALUES IN THAT COLUMN

# %%
df.isnull().sum()
# Out:
# ID                 0
# Marital-Status     0
# Gender             0
# Income             0
# Children           0
# Education          0
# Occupation         0
# HomeOwner          0
# Cars               0
# CommuteDistance    0
# Region             0
# Age                0
# dtype: int64

# %%
np.unique(df['Occupation'])
# Out:
# array(['Clerical', 'Management', 'Manual', 'Professional',
#        'Skilled Manual'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array(['Skilled Manual', 'Clerical', 'Professional', 'Manual',
#        'Management'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# Stripping all the spaces of the columns using str.strip() function

# %%
strip_columns = ['ID','Marital-Status','Gender','Income','Children','Education','Occupation','HomeOwner','Cars','CommuteDistance','Region','Age']

# %%
df.describe(include = 'O').T
# Out:
#                 count unique            top freq
# Marital-Status   1000      2        Married  539
# Gender           1000      2           Male  509
# Education        1000      5      Bachelors  306
# Occupation       1000      5   Professional  276
# HomeOwner        1000      2            Yes  685
# CommuteDistance  1000      5      0-1 Miles  366
# Region           1000      3  North America  508

# %% [markdown]
# Finding Categorical Values and Numerical Values

# %%
categorical = [i for i in df.columns if df[i].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))

print('The categorical variables are :\n\n', categorical)
# Out:
# There are 7 categorical variables
#
# The categorical variables are :
#
#  ['Marital-Status', 'Gender', 'Education', 'Occupation', 'HomeOwner', 'CommuteDistance', 'Region']

# %%
numerical = [var for var in df.columns if df[var].dtype=='int64']

print('There are {} numerical variables\n'.format(len(numerical)))

print('The numerical variables are :\n\n', numerical)
# Out:
# There are 5 numerical variables
#
# The numerical variables are :
#
#  ['ID', 'Income', 'Children', 'Cars', 'Age']

# %%
for var in categorical:
    print(df[var].value_counts())
# Out:
# Married    539
# Single     461
# Name: Marital-Status, dtype: int64
# Male      509
# Female    491
# Name: Gender, dtype: int64
# Bachelors              306
# Partial College        265
# High School            179
# Graduate Degree        174
# Partial High School     76
# Name: Education, dtype: int64
# Professional      276
# Skilled Manual    255
# Clerical          177
# Management        173
# Manual            119
# Name: Occupation, dtype: int64
# Yes    685
# No     315
# Name: HomeOwner, dtype: int64
# 0-1 Miles     366
# 5-10 Miles    192
# 1-2 Miles     169
# 2-5 Miles     162
# 10+ Miles     111
# Name: CommuteDistance, dtype: int64
# North America    508
# Europe           300
# Pacific          192
# Name: Region, dtype: int64

# %%
df.loc[df['Marital-Status']=='?']
# Out:
# Empty DataFrame
# Columns: [ID, Marital-Status, Gender, Income, Children, Education, Occupation, HomeOwner, Cars, CommuteDistance, Region, Age]
# Index: []

# %%
df.loc[df['Marital-Status']=='?', 'Marital-Status']= np.NaN

# %%
df['Marital-Status'].value_counts()/len(df)
# Out:
# Married    0.539
# Single     0.461
# Name: Marital-Status, dtype: float64

# %%
more_than_50 = df[df['Cars'] == '>50K']
less_than_50 = df[df['Income'] == '<=50K']
print (more_than_50.shape,less_than_50.shape)
# Out:
# (0, 12) (0, 12)

# %% [markdown]
# DATA VISUALIZATION

# %%
df.head()
# Out:
#       ID Marital-Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation HomeOwner  Cars CommuteDistance   Region  Age
# 0  Skilled Manual       Yes     0       0-1 Miles   Europe   42
# 1        Clerical       Yes     1       0-1 Miles   Europe   43
# 2    Professional        No     2       2-5 Miles   Europe   60
# 3    Professional       Yes     1      5-10 Miles  Pacific   41
# 4        Clerical        No     0       0-1 Miles   Europe   36

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f,ax=plt.subplots(1,2,figsize=(10,10))

ax[0] = df['Cars'].value_counts().plot.pie(subplots=False,autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Car Share')


#f, ax = plt.subplots(figsize=(6, 8))
ax[1] = sns.countplot(x="Cars", data=df, palette="Set1")
ax[1].set_title("Frequency distribution of Car variable")

plt.show()

# %% [markdown]
# The above dataset shows us that people owning 2 cars are more in number followed by owning 1 car and later 0

# %%
#f, ax = plt1.subplots(figsize=(10,10))
ax = sns.countplot(x="Gender",hue="Income", data=df)

ax.set_title("Frequency distribution of Income wrt to Gender")

plt1.show()

# %% [markdown]
# Income of Male is greater than female

# %%
f,ax = plt1.subplots(figsize=(10, 8))

ax = sns.countplot(x="Income", hue="Marital-Status", data=df)

ax.set_title("Frequency distribution of income variable wrt Marital-Status")

plt1.show()

# %% [markdown]
# Married indivisuals have a greater income compared to singles

# %%
f, ax = plt1.subplots(figsize=(15,5))

ax = sns.countplot(x="Income", hue="Education", data=df, palette="Set1")

ax.set_title("Frequency distribution of income variable wrt Marital_Status")

plt1.show()

# %% [markdown]
# Income of indivisual is really high if they have completed their bachelors followed by partial college

# %%
temp_3 = df.loc[(df['Income']=='>50K') & (df['Education'] == 'HS-grad')]

# %%
df.loc[(df['Children']=='>5') & (df['Education'] == 'Partial College')]
# Out:
# Empty DataFrame
# Columns: [ID, Marital-Status, Gender, Income, Children, Education, Occupation, HomeOwner, Cars, CommuteDistance, Region, Age]
# Index: []

# %%
plt1.figure(figsize=(10,4))
plt1.title('Boxplot for the Income & Cars')
sns.boxplot( data=df[['Income','Cars']], orient='f')
plt1.show()

# %% [markdown]
# There are couple of outlier in Income

# %% [markdown]
# Dropping these outliers as it can lead to the result distortion

# %%
abc = df.loc[df['Income']>90000,'Cars'].index
df.drop(index=abc,inplace=True)

# %%
sns.histplot(x=df['Income'],palette='Set1',bins=20)
plt1.title("The Histogram for Income")
plt1.show()
# Out:
# C:\Users\TEJAS\AppData\Local\Temp\ipykernel_35260\2657377507.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df['Income'],palette='Set1',bins=20)

# %%
for i in numerical:
    sns.histplot(x=df[i], palette='Set1',bins=20)
    plt1.title("The Histogram for {}".format(i))
    plt1.show()
# Out:
# C:\Users\TEJAS\AppData\Local\Temp\ipykernel_35260\2404064608.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)
# C:\Users\TEJAS\AppData\Local\Temp\ipykernel_35260\2404064608.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)
# C:\Users\TEJAS\AppData\Local\Temp\ipykernel_35260\2404064608.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)
# C:\Users\TEJAS\AppData\Local\Temp\ipykernel_35260\2404064608.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)
# C:\Users\TEJAS\AppData\Local\Temp\ipykernel_35260\2404064608.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df[i], palette='Set1',bins=20)

# %% [markdown]
# Histogram of Age is negatively skewed

# %%
sns.pairplot(data=df, hue="Income")
plt1.title('Distributions for each variable')
plt1.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(20,20))
axs = axs.flatten()
fig.suptitle('Relation between the categorical features and Cars')

categorical2 =['Marital-Status', 'Gender', 'Education', 'Occupation', 'HomeOwner', 'CommuteDistance', 'Region']
for ax, i in enumerate(categorical2):
    sns.countplot(x='Cars', alpha=0.7, hue=i, ax=axs[ax], data=df,palette='Set1')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\TEJAS\OneDrive\Desktop\VSC\LAB_ BIKE 1.ipynb Cell 61 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/TEJAS/OneDrive/Desktop/VSC/LAB_%20BIKE%201.ipynb#Y120sZmlsZQ%3D%3D?line=4'>5</a> categorical2 =['Marital-Status', 'Gender', 'Education', 'Occupation', 'HomeOwner', 'CommuteDistance', 'Region']
#       <a href='vscode-notebook-cell:/c%3A/Users/TEJAS/OneDrive/Desktop/VSC/LAB_%20BIKE%201.ipynb#Y120sZmlsZQ%3D%3D?line=5'>6</a> for ax, i in enumerate(categorical2):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/TEJAS/OneDrive/Desktop/VSC/LAB_%20BIKE%201.ipynb#Y120sZmlsZQ%3D%3D?line=6'>7</a>     sns.countplot(x='Cars', alpha=0.7, hue=i, ax=axs[ax], data=df,palette='Set1')
#
# IndexError: index 6 is out of bounds for axis 0 with size 6

# %%
corr = df.corr()
sns.heatmap(corr, annot=True)
plt1.title('Correlation matrix')
plt1.show()
# Out:
# C:\Users\TEJAS\AppData\Local\Temp\ipykernel_35260\322799722.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# This matrix will show us how the variables are correlated with each other

# %%
X = df.drop(columns='ID')
X
# Out:
#     Marital-Status  Gender  Income  Children        Education      Occupation  \
# 0          Married  Female   40000         1        Bachelors  Skilled Manual
# 1          Married    Male   30000         3  Partial College        Clerical
# 2          Married    Male   80000         5  Partial College    Professional
# 3           Single    Male   70000         0        Bachelors    Professional
# 4           Single    Male   30000         0        Bachelors        Clerical
# ..             ...     ...     ...       ...              ...             ...
# 994        Married    Male   80000         5  Partial College    Professional
# 995        Married    Male   60000         2      High School    Professional
# 996         Single    Male   70000         4  Graduate Degree    Professional
# 997        Married    Male   60000         2        Bachelors  Skilled Manual
# 999         Single    Male   60000         3      High School    Professional
#
# ...

# %% [markdown]
# Drop the ID variable which is negatively correlated with other variabels
